# %%
metabolomics_negative_file = '/home/adrian/projects/covidthelium/data/FRANCE_PLASMA_Metabolomics_NEG_19042022_IS.csv'
metadata_file = '/home/adrian/projects/covidthelium/data/DATABASE Iceland.xlsx'

# %%
#

# %%
import pandas

# %%
df = pandas.read_csv(metabolomics_negative_file, sep=',')
df
# Out:
#       Unnamed: 0          mz       mzmin       mzmax        rt   rt(min)  IS  \
# 0              1   55.016764   55.015208   55.019731  254.5270  4.242117   0
# 1              2   57.032757   57.031443   57.034488   74.9885  1.249808   0
# 2              3   57.032563   57.031558   57.035333  116.7190  1.945317   0
# 3              4   58.026901   58.024875   58.029176  254.2025  4.236708   0
# 4              5   59.011901   59.010453   59.013383  213.2170  3.553617   0
# ...          ...         ...         ...         ...       ...       ...  ..
# 3572        3573  998.092210  998.082972  998.100040  221.2480  3.687467   0
# 3573        3574  998.116207  998.109930  998.127162  221.0365  3.683942   0
# 3574        3575  999.271766  999.262859  999.280086  233.2800  3.888000   0
# 3575        3576  999.894982  999.888861  999.906107  244.2930  4.071550   0
# 3576        3577  999.917326  999.906426  999.923369  243.8085  4.063475   0
#
# ...

# %%
samples = df.columns.to_list()
samples = [element for element in samples if 'France' in element]
print(len(samples), samples)
# Out:
# 117 ['France_Plasma_100', 'France_Plasma_101', 'France_Plasma_102', 'France_Plasma_103', 'France_Plasma_104', 'France_Plasma_105', 'France_Plasma_106', 'France_Plasma_107', 'France_Plasma_108', 'France_Plasma_109', 'France_Plasma_110', 'France_Plasma_111', 'France_Plasma_112', 'France_Plasma_113', 'France_Plasma_114', 'France_Plasma_115', 'France_Plasma_116', 'France_Plasma_117', 'France_Plasma_118', 'France_Plasma_119', 'France_Plasma_120', 'France_Plasma_121', 'France_Plasma_122', 'France_Plasma_123', 'France_Plasma_124', 'France_Plasma_125', 'France_Plasma_126', 'France_Plasma_127', 'France_Plasma_128', 'France_Plasma_129', 'France_Plasma_130', 'France_Plasma_131', 'France_Plasma_132', 'France_Plasma_133', 'France_Plasma_134', 'France_Plasma_135', 'France_Plasma_136', 'France_Plasma_137', 'France_Plasma_138', 'France_Plasma_139', 'France_Plasma_140', 'France_Plasma_141', 'France_Plasma_142', 'France_Plasma_143', 'France_Plasma_144', 'France_Plasma_85', 'France_Plasma_86', 'France_
# ...

# %%
metadata = pandas.read_excel(metadata_file, sheet_name='data brut')

# %%
metadata
# Out:
#     Number Initial   RBC    Hb  reticulotcytes  Platelets  Leukocytes    PNN  \
# 0        1      LP  4.76  14.0          25.704      136.0        4.27   3.85
# 1        2      SP  4.42  12.9             NaN      846.0        5.50   4.85
# 2        3      BL  3.14   9.2          13.502      483.0        6.80   6.15
# 3        4      LS  3.14   9.1          29.202      264.0       21.50  20.55
# 4        5      AB  5.24  12.7          38.252      335.0       11.64  10.57
# ..     ...     ...   ...   ...             ...        ...         ...    ...
# 91      96      LD  4.68  14.3          44.928      345.0        5.29   4.06
# 92      97      PP  4.24  13.4          24.168      374.0        6.60   5.95
# 93      98      MS  3.72  12.0          18.600      164.0        4.38   3.40
# 94      99      ME  5.43  15.2          83.079      562.0       20.26  18.30
# 95     100      FJ  4.62  14.3          32.802      140.0        4.25   3.52
#
# ...
