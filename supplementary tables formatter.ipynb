# %%
import pandas

# %%
input_file = '/Users/adrian/research/covithelium/results/module_annotation/pathways_table_all_modules_APR2024_NEW.csv'

# %%
df = pandas.read_csv(input_file, index_col=6)
df.drop(labels=['Module ID', 'Unnamed: 0'], axis=1, inplace=True)
df.index.rename('Module ID', inplace=True)
df.rename(columns={'No.feat':'Number of features in module'}, inplace=True)
df.head()
# Out:
#                                    Representative feature(s)  \
# Module ID
# 1                                           ['Urobilinogen']
# 2          ['Acetyl-N-formyl-5-methoxykynurenamine' 'Phen...
# 3          ['Norepinephrine' 'Pyridoxine' 'p-Hydroxypheny...
# 4                                   ['Tetrahydrofolic acid']
# 5          ['PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))'\n...
#
#            Number of features in module  \
# Module ID
# 1                                     9
# 2                                    66
# 3                                    38
# 4                                     1
# 5                                    12
#
#                                                     Pathways  \
# Module ID
# 1                                   ['Porphyrin Metabolism']
# 2          ['Tryptophan Metabolism' 'Phenylacetate Metabo...
# 3          ['Thyroid Hormone Synthesis' 'Tyrosine Metabol...
# 4             ['Betaine Metabolism' 'Methionine Metabolism']
# 5          ['Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z...
#
#                                             Pathway p.values
# Module ID
# 1                                                 [0.000999]
# 2          [0.000999   0.002997   0.01198801 0.01898102 0...
# 3          [0.000999   0.000999   0.001998   0.002997   0...
# 4                                    [0.03296703 0.04695305]
# 5          [0.000999 0.000999 0.000999 0.000999 0.000999 ...

# %%
# deal with features
translate_table = {ord("'") : None, 
               ord('[') : None, 
               ord(']') : None}

formatted_features = []
for feature in df['Representative feature(s)']:
    formatted_names = []
    feature = feature.replace('\n', '')
    names = feature.split("' '")
    for name in names:
        new = name.translate(translate_table)
        formatted_names.append(new)
    formatted_names_string = ", ".join(formatted_names)
    formatted_features.append(formatted_names_string)

df['Annotations for representative feature'] = formatted_features
df.head()
# Out:
#                                    Representative feature(s)  \
# Module ID
# 1                                           ['Urobilinogen']
# 2          ['Acetyl-N-formyl-5-methoxykynurenamine' 'Phen...
# 3          ['Norepinephrine' 'Pyridoxine' 'p-Hydroxypheny...
# 4                                   ['Tetrahydrofolic acid']
# 5          ['PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))'\n...
#
#            Number of features in module  \
# Module ID
# 1                                     9
# 2                                    66
# 3                                    38
# 4                                     1
# 5                                    12
#
#                                                     Pathways  \
# Module ID
# 1                                   ['Porphyrin Metabolism']
# 2          ['Tryptophan Metabolism' 'Phenylacetate Metabo...
# 3          ['Thyroid Hormone Synthesis' 'Tyrosine Metabol...
# 4             ['Betaine Metabolism' 'Methionine Metabolism']
# 5          ['Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z...
#
#                                             Pathway p.values  \
# Module ID
# 1                                                 [0.000999]
# 2          [0.000999   0.002997   0.01198801 0.01898102 0...
# 3          [0.000999   0.000999   0.001998   0.002997   0...
# 4                                    [0.03296703 0.04695305]
# 5          [0.000999 0.000999 0.000999 0.000999 0.000999 ...
#
#                       Annotations for representative feature
# Module ID
# 1                                               Urobilinogen
# 2          Acetyl-N-formyl-5-methoxykynurenamine, Phenyla...
# 3          Norepinephrine, Pyridoxine, p-Hydroxyphenylace...
# 4                                       Tetrahydrofolic acid
# 5          PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z)), PG(...

# %%
# deal with enriched pathways
translate_table = {ord("'") : None, 
               ord('[') : None, 
               ord(']') : None}

formatted_features = []
for feature in df['Pathways']:
    #print(feature)
    formatted_names = []
    feature = feature.replace('\n', '')
    names = feature.split("' '")
    for name in names:
        new = name.translate(translate_table)
        formatted_names.append(new)
    formatted_names_string = ", ".join(formatted_names)
    formatted_features.append(formatted_names_string)
    #print(formatted_names_string)
    #print()

df['Enriched pathways'] = formatted_features
df.head()
# Out:
#                                    Representative feature(s)  \
# Module ID
# 1                                           ['Urobilinogen']
# 2          ['Acetyl-N-formyl-5-methoxykynurenamine' 'Phen...
# 3          ['Norepinephrine' 'Pyridoxine' 'p-Hydroxypheny...
# 4                                   ['Tetrahydrofolic acid']
# 5          ['PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))'\n...
#
#            Number of features in module  \
# Module ID
# 1                                     9
# 2                                    66
# 3                                    38
# 4                                     1
# 5                                    12
#
#                                                     Pathways  \
# Module ID
# 1                                   ['Porphyrin Metabolism']
# 2          ['Tryptophan Metabolism' 'Phenylacetate Metabo...
# 3          ['Thyroid Hormone Synthesis' 'Tyrosine Metabol...
# 4             ['Betaine Metabolism' 'Methionine Metabolism']
# 5          ['Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z...
#
#                                             Pathway p.values  \
# Module ID
# 1                                                 [0.000999]
# 2          [0.000999   0.002997   0.01198801 0.01898102 0...
# 3          [0.000999   0.000999   0.001998   0.002997   0...
# 4                                    [0.03296703 0.04695305]
# 5          [0.000999 0.000999 0.000999 0.000999 0.000999 ...
#
#                       Annotations for representative feature  \
# Module ID
# 1                                               Urobilinogen
# 2          Acetyl-N-formyl-5-methoxykynurenamine, Phenyla...
# 3          Norepinephrine, Pyridoxine, p-Hydroxyphenylace...
# 4                                       Tetrahydrofolic acid
# 5          PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z)), PG(...
#
#                                            Enriched pathways
# Module ID
# 1                                       Porphyrin Metabolism
# 2          Tryptophan Metabolism, Phenylacetate Metabolis...
# 3          Thyroid Hormone Synthesis, Tyrosine Metabolism...
# 4                  Betaine Metabolism, Methionine Metabolism
# 5          Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z,7...

# %%
# deal with P values
translate_table = {ord("'") : None, 
               ord('[') : None, 
               ord(']') : None}

formatted_features = []
for feature in df['Pathway p.values']:
    print(feature)
    formatted_names = []
    feature = feature.replace('\n', '')
    names = feature.split()
    for name in names:
        new = name.translate(translate_table)
        formatted_names.append(new)
    formatted_names_string = ", ".join(formatted_names)
    formatted_features.append(formatted_names_string)
    print(formatted_names_string)
    print()

df['Enrichments P'] = formatted_features
df.head()
# Out:
# [0.000999]
# 0.000999
#
# [0.000999   0.002997   0.01198801 0.01898102 0.03096903]
# 0.000999, 0.002997, 0.01198801, 0.01898102, 0.03096903
#
# [0.000999   0.000999   0.001998   0.002997   0.00799201 0.01098901
#  0.01598402 0.04595405]
# 0.000999, 0.000999, 0.001998, 0.002997, 0.00799201, 0.01098901, 0.01598402, 0.04595405
#
# [0.03296703 0.04695305]
# 0.03296703, 0.04695305
#
# [0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999 0.000999
#  0.000999 0.000999 0.000999 0.000999 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998 0.001998
#  0.001998 0.002997 0.002997 0.002997 0.002997 0.002997 0.002997 0.002997
#  0.002997 0.002997 0.002997 0.002997 0.002997 0.002997 0.002997 0.002997
#  0.002997 0.002997 0.002997 0.003996 0.003996 0.003996 0.003996 0.003996
#  0.004995]
# 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.000999, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.001998, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.002997, 0.003996, 0.003996, 0.003996, 0.003996, 0.003996, 0.004995
#
# [0.00599401 0.04095904]
# 0.00599401, 0.04095904
#
# [0.00599401 0.01298701]
# 0.00599401, 0.01298701
#
# [0.03696304]
# 0.03696304
#
# []
#
#
# [0.02697303 0.03196803 0.04295704]
# 0.02697303, 0.03196803, 0.04295704
#
# [0.03796204 0.03996004 0.03996004]
# 0.03796204, 0.03996004, 0.03996004
#
# [0.000999 0.001998]
# 0.000999, 0.001998
#
# [0.02397602]
# 0.02397602
#
# [0.000999   0.002997   0.004995   0.00599401 0.00699301 0.00699301
#  0.00799201 0.00799201 0.00899101 0.01298701]
# 0.000999, 0.002997, 0.004995, 0.00599401, 0.00699301, 0.00699301, 0.00799201, 0.00799201, 0.00899101, 0.01298701
#
# []
#
#
# [0.02497502 0.03096903 0.03296703 0.03496503 0.03696304 0.04495504
#  0.04695305 0.04895105]
# 0.02497502, 0.03096903, 0.03296703, 0.03496503, 0.03696304, 0.04495504, 0.04695305, 0.04895105
#
# [0.000999   0.000999   0.002997   0.003996   0.003996   0.003996
#  0.004995   0.00599401 0.00599401 0.00599401 0.00699301 0.00699301
#  0.00699301 0.00699301 0.00799201 0.00999001 0.00999001 0.01098901
#  0.02397602 0.02997003 0.04895105]
# 0.000999, 0.000999, 0.002997, 0.003996, 0.003996, 0.003996, 0.004995, 0.00599401, 0.00599401, 0.00599401, 0.00699301, 0.00699301, 0.00699301, 0.00699301, 0.00799201, 0.00999001, 0.00999001, 0.01098901, 0.02397602, 0.02997003, 0.04895105
#
# []
#
#
# [0.01798202 0.04295704 0.04295704]
# 0.01798202, 0.04295704, 0.04295704
#
# [0.01198801]
# 0.01198801
#
# []
#
#
# []
#
#
# [0.00599401 0.01298701 0.01598402 0.02097902 0.03596404 0.04295704]
# 0.00599401, 0.01298701, 0.01598402, 0.02097902, 0.03596404, 0.04295704
#
# [0.000999]
# 0.000999
#
# [0.03296703]
# 0.03296703
#
# [0.001998   0.004995   0.004995   0.004995   0.00599401 0.00599401
#  0.02197802]
# 0.001998, 0.004995, 0.004995, 0.004995, 0.00599401, 0.00599401, 0.02197802
#
# []
#
#
# [0.01998002]
# 0.01998002
#
# [0.000999]
# 0.000999
#
# [0.02197802]
# 0.02197802
#
# [0.01398601 0.02297702 0.03096903 0.04895105]
# 0.01398601, 0.02297702, 0.03096903, 0.04895105
#
# [0.00999001 0.01198801 0.01298701 0.01798202 0.01998002 0.03696304
#  0.04195804 0.04495504 0.04595405 0.04595405 0.04795205 0.04895105]
# 0.00999001, 0.01198801, 0.01298701, 0.01798202, 0.01998002, 0.03696304, 0.04195804, 0.04495504, 0.04595405, 0.04595405, 0.04795205, 0.04895105
#
# [0.01198801 0.01698302 0.03496503 0.04495504]
# 0.01198801, 0.01698302, 0.03496503, 0.04495504
#
# [0.000999   0.001998   0.01198801 0.02297702 0.03996004]
# 0.000999, 0.001998, 0.01198801, 0.02297702, 0.03996004
#
# [0.000999]
# 0.000999
#
# [0.004995   0.00999001]
# 0.004995, 0.00999001
#
# [0.01098901 0.01698302 0.02197802 0.03596404 0.04795205]
# 0.01098901, 0.01698302, 0.02197802, 0.03596404, 0.04795205
#
# []
#
#
# []
#
#
# [0.01998002 0.02297702 0.03596404 0.04095904]
# 0.01998002, 0.02297702, 0.03596404, 0.04095904
#
# [0.000999   0.001998   0.001998   0.001998   0.003996   0.003996
#  0.004995   0.00599401 0.00599401 0.00599401 0.00699301 0.00899101
#  0.01098901 0.01398601 0.01598402 0.01698302]
# 0.000999, 0.001998, 0.001998, 0.001998, 0.003996, 0.003996, 0.004995, 0.00599401, 0.00599401, 0.00599401, 0.00699301, 0.00899101, 0.01098901, 0.01398601, 0.01598402, 0.01698302
#
# []
#
#
# []
#
#
# [0.00799201]
# 0.00799201
#
# [0.01298701 0.04995005]
# 0.01298701, 0.04995005
#
# [0.00799201 0.01898102 0.02697303]
# 0.00799201, 0.01898102, 0.02697303
#
# []
#
#
# [0.03096903]
# 0.03096903
#
# [0.02297702 0.03396603 0.03696304 0.03896104 0.04695305 0.04795205
#  0.04995005]
# 0.02297702, 0.03396603, 0.03696304, 0.03896104, 0.04695305, 0.04795205, 0.04995005
#
# [0.02997003]
# 0.02997003
#
# [0.02197802 0.02597403 0.02897103 0.03896104 0.03996004 0.04295704
#  0.04395604 0.04495504 0.04495504 0.04695305]
# 0.02197802, 0.02597403, 0.02897103, 0.03896104, 0.03996004, 0.04295704, 0.04395604, 0.04495504, 0.04495504, 0.04695305
#                                    Representative feature(s)  \
# Module ID
# 1                                           ['Urobilinogen']
# 2          ['Acetyl-N-formyl-5-methoxykynurenamine' 'Phen...
# 3          ['Norepinephrine' 'Pyridoxine' 'p-Hydroxypheny...
# 4                                   ['Tetrahydrofolic acid']
# 5          ['PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z))'\n...
#
#            Number of features in module  \
# Module ID
# 1                                     9
# 2                                    66
# 3                                    38
# 4                                     1
# 5                                    12
#
#                                                     Pathways  \
# Module ID
# 1                                   ['Porphyrin Metabolism']
# 2          ['Tryptophan Metabolism' 'Phenylacetate Metabo...
# 3          ['Thyroid Hormone Synthesis' 'Tyrosine Metabol...
# 4             ['Betaine Metabolism' 'Methionine Metabolism']
# 5          ['Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z...
#
#                                             Pathway p.values  \
# Module ID
# 1                                                 [0.000999]
# 2          [0.000999   0.002997   0.01198801 0.01898102 0...
# 3          [0.000999   0.000999   0.001998   0.002997   0...
# 4                                    [0.03296703 0.04695305]
# 5          [0.000999 0.000999 0.000999 0.000999 0.000999 ...
#
#                       Annotations for representative feature  \
# Module ID
# 1                                               Urobilinogen
# 2          Acetyl-N-formyl-5-methoxykynurenamine, Phenyla...
# 3          Norepinephrine, Pyridoxine, p-Hydroxyphenylace...
# 4                                       Tetrahydrofolic acid
# 5          PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z)), PG(...
#
#                                            Enriched pathways  \
# Module ID
# 1                                       Porphyrin Metabolism
# 2          Tryptophan Metabolism, Phenylacetate Metabolis...
# 3          Thyroid Hormone Synthesis, Tyrosine Metabolism...
# 4                  Betaine Metabolism, Methionine Metabolism
# 5          Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z,7...
#
#                                                Enrichments P
# Module ID
# 1                                                   0.000999
# 2          0.000999, 0.002997, 0.01198801, 0.01898102, 0....
# 3          0.000999, 0.000999, 0.001998, 0.002997, 0.0079...
# 4                                     0.03296703, 0.04695305
# 5          0.000999, 0.000999, 0.000999, 0.000999, 0.0009...

# %%
# reorder
storage = df.loc[:, ['Number of features in module', 
           'Annotations for representative feature', 
           'Enriched pathways', 
           'Enrichments P']]
storage.head()
# Out:
#            Number of features in module  \
# Module ID
# 1                                     9
# 2                                    66
# 3                                    38
# 4                                     1
# 5                                    12
#
#                       Annotations for representative feature  \
# Module ID
# 1                                               Urobilinogen
# 2          Acetyl-N-formyl-5-methoxykynurenamine, Phenyla...
# 3          Norepinephrine, Pyridoxine, p-Hydroxyphenylace...
# 4                                       Tetrahydrofolic acid
# 5          PG(18:1(11Z)/22:6(4Z,7Z,10Z,13Z,16Z,19Z)), PG(...
#
#                                            Enriched pathways  \
# Module ID
# 1                                       Porphyrin Metabolism
# 2          Tryptophan Metabolism, Phenylacetate Metabolis...
# 3          Thyroid Hormone Synthesis, Tyrosine Metabolism...
# 4                  Betaine Metabolism, Methionine Metabolism
# 5          Cardiolipin Biosynthesis CL(18:1(9Z)/22:6(4Z,7...
#
#                                                Enrichments P
# Module ID
# 1                                                   0.000999
# 2          0.000999, 0.002997, 0.01198801, 0.01898102, 0....
# 3          0.000999, 0.000999, 0.001998, 0.002997, 0.0079...
# 4                                     0.03296703, 0.04695305
# 5          0.000999, 0.000999, 0.000999, 0.000999, 0.0009...

# %%
#store
storage.to_csv('formatted_table_modules.tsv', sep='\t')
